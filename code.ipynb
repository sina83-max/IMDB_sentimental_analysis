# %%
import pandas as pd

# %%
df = pd.read_csv('IMDB Dataset.csv')
# print(df['sentiment'].value_counts())

df['review_length'] = df['review'].apply(lambda x: len(x.split()))
df['review_length'].plot(kind='hist', bins=50)
# Out:
# <Axes: ylabel='Frequency'>

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

positive_reviews = df[df['sentiment'] == 'positive']['review']
negative_reviews = df[df['sentiment'] == 'negative']['review']

wordcloud_positive = WordCloud(width=800, height=400).generate(" ".join(positive_reviews))
plt.imshow(wordcloud_positive, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
import string

nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')


stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()
# Out:
# [nltk_data] Downloading package punkt to /Users/sina/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /Users/sina/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /Users/sina/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
